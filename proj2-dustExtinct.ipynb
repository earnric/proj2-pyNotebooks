# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from extinction import calzetti00, apply
from extinction import ccm89, fm07
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
plt.rcParams['figure.figsize'] = (13,11)
plt.rcParams['font.size'] = 32

# %%
wave = np.arange(900.,20001.)
flux = np.ones(len(wave))
print(len(wave),len(flux))

fig = plt.figure(figsize=(10,4))
ax = plt.axes()
ax.set_xscale('log')
ax.set_yscale('linear')
#ax.plot(wave,apply(ccm89(wave,1.0,3.1),flux))
ax.plot(wave,ccm89(wave,1.0,3.1),'b-')
ax.plot(wave,calzetti00(wave,1.0,3.1),'k-')
ax.plot(wave,fm07(wave,1.0),'r-')
ax.set_xlim([900,20000])
ax.set_ylim([0,16])
# Out:
# 19101 19101
# (0, 16)
