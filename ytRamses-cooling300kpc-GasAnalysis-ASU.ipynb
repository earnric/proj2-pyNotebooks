# %%
import yt
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-00058a6f4819> in <module>()
# ----> 1 import yt
#       2 import matplotlib.pyplot as plt
#       3 from mpl_toolkits.axes_grid1 import AxesGrid
#
# /Users/earnric/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/yt/__init__.pyc in <module>()
#     114     derived_field
#     115
# --> 116 from yt.data_objects.api import \
#     117     BinnedProfile1D, BinnedProfile2D, BinnedProfile3D, \
#     118     DatasetSeries, \
#
# /Users/earnric/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/yt/data_objects/api.py in <module>()
#      14 #-----------------------------------------------------------------------------
#      15
# ---> 16 from .grid_patch import \
#      17     AMRGridPatch
#      18
#
# ...

# %% [markdown]
# ## Gas temperature - weighted by density through sim volume

# %%
fns = ["/Users/earnric/RAMSES-Data/coolingFixedTau/output_00008/info_00008.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00008/info_00008.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Projection")

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.ProjectionPlot(ds, 'z', 'temperature', weight_field="density")

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "${H_2}$ cooling "
    else:
        ptype = "Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# WARNING:yt:RAMSES frontend assumes all simulations are cosmological!
# WARNING:yt:RAMSES frontend assumes all simulations are cosmological!
# <img src="data:image/png;base64,..."><br>

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00010/info_00010.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00010/info_00010.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Projection")

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.ProjectionPlot(ds, 'z', 'temperature', weight_field="density")

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "${H_2}$ cooling "
    else:
        ptype = "Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %% [markdown]
# ### Gas temp slice...

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00010/info_00010.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00010/info_00010.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Slices")
L = [0,0,1] # vector normal to cutting plane
for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.SlicePlot(ds, 'z', 'temperature')

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "Slice - ${H_2}$ cooling "
    else:
        ptype = "Slice - Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
fns = ["/Users/earnric/RAMSES-Data/coolingFixedTau/output_00013/info_00013.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00013/info_00013.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature")

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.ProjectionPlot(ds, 'z', 'temperature', weight_field="density")

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "${H_2}$ cooling "
    else:
        ptype = "Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# WARNING:yt:RAMSES frontend assumes all simulations are cosmological!
# WARNING:yt:RAMSES frontend assumes all simulations are cosmological!
# <img src="data:image/png;base64,..."><br>

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00013/info_00013.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00013/info_00013.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Slices")
L = [0,0,1] # vector normal to cutting plane
for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.SlicePlot(ds, 'z', 'temperature')

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "Slice - ${H_2}$ cooling "
    else:
        ptype = "Slice - Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00013/info_00013.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00013/info_00013.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Slices")

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.SlicePlot(ds, 'z', 'temperature', center=[0.5, 0.5, 0.6] )

    # Ensure the colorbar limits match for all plots
    p.set_zlim('temperature', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['temperature']
    if i % 2 == 0:
        ptype = "Slice - ${H_2}$ cooling +10% zcoord"
    else:
        ptype = "Slice - Standard cooling +10% zcoord"
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
# Get a sphere on the 'center' with size of the sim ... Can use for phase plot
my_sphere = ds.sphere("c", physSize)

# %% [markdown]
# ## Gas phase diagrams...

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00013/info_00013.txt",
       "/Users/earnric/RAMSES-Data/noCool/output_00013/info_00013.txt"]

fields = ["density","temperature"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Temperature - Slices")
L = [0,0,1] # vector normal to cutting plane
for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn) # load data
    p = yt.PhasePlot(ad, "density", "temperature", "cell_mass", x_bins=256, y_bins=256, weight_field=None, fractional=True )

    # Ensure the colorbar limits match for all plots
    p.set_zlim('cell_mass', 0.1, 1e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots['cell_mass']
    if i % 2 == 0:
        ptype = "Gas phase - ${H_2}$ cooling"
    else:
        ptype = "Gas phase - Standard cooling"
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
    #p.annotate_title(zStr) # YOU HAVE TO DO THIS AFTER THE AXES calls
    # Finally, this actually redraws the plot.
    p._setup_plots()
p.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
fns = [ "/Users/earnric/RAMSES-Data/coolingFixedTau/output_00010/info_00010.txt"]

fig = plt.figure()
grid = AxesGrid(fig, (0.075,0.075,0.85,0.85),
                nrows_ncols = (1, 2),
                axes_pad = 0.05,
                label_mode = "L",
                share_all = True,
                cbar_location="right",
                cbar_mode="single",
                cbar_size="3%",
                cbar_pad="0%")
fig.suptitle("Gas Phase")

for i, fn in enumerate(fns):
    ds = yt.load(fn)
    ad = ds.all_data()
    # fractional=True keyword -- divide the profile data by the sum. 
    p = yt.PhasePlot(ad, "density", "temperature", "cell_mass", x_bins=256, y_bins=256, weight_field=None, fractional=True )
    plot = p
    if i % 2 == 0:
        ptype = "Gas phase ${H_2}$ cooling "
    else:
        ptype = "Gas phase Standard cooling "
    zStr = ptype + "z = %.1f" % ds.current_redshift 
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]

    p['cell_mass'].axes.set_ylim (1e-1, 1e6)
    p['cell_mass'].axes.set_xlim (1e-29, 1e-24)
    p['cell_mass'].axes.set_title(zStr, fontsize=20)
plot.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
# fractional=True keyword -- divide the profile data by the sum. 
ds = yt.load("/Users/earnric/RAMSES-Data/noCool/output_00010/info_00010.txt")
ad = ds.all_data()
plot = yt.PhasePlot(ad, "density", "temperature", "cell_mass", x_bins=256, y_bins=256, weight_field=None, fractional=True )
zStr = "Gas phase, No $H_2$ cooling z = %.1f" % ds.current_redshift
plot.set_zlim('cell_mass', 1e-9, 1e-1)
plot['cell_mass'].axes.set_ylim (1e-1, 1e6)
plot['cell_mass'].axes.set_xlim (1e-29, 1e-24)
plot['cell_mass'].axes.set_title(zStr, fontsize=20)
plot.show()
# Out:
# <img src="data:image/png;base64,..."><br>
