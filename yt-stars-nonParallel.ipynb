# %%
import yt

# %%
import os, sys
print os.getenv("PATH")
print sys.path
# Out:
# /opt/apps/intel14/hdf5/1.8.13/x86_64/bin:/opt/apps/intel14/mvapich2_2_0/python/2.7.6/bin:/opt/apps/intel14/mvapich2/2.0b/bin:/opt/apps/intel/13/vtune_amplifier_xe_2013/bin64:/opt/apps/intel/13/composer_xe_2013_sp1.1.106/mpirt/bin/intel64:/opt/intel/sep/bin:/opt/apps/xalt/0.4.6/bin:/home1/02744/earnric/.local/bin:/home1/02744/earnric/work/python/bin:/home1/02744/earnric/.local/bin:/usr/lib64/qt-3.3/bin:/usr/local/bin:/bin:/usr/bin:/opt/apps/xsede/gsi-openssh-5.7/bin:/opt/ofed/bin:/opt/ofed/sbin:/usr/X11R6/bin:.:/opt/apps/intel/13/composer_xe_2013_sp1.1.106/bin/intel64:/opt/apps/intel/13/composer_xe_2013_sp1.1.106/bin/intel64_mic:/opt/apps/intel/13/composer_xe_2013_sp1.1.106/debugger/gui/intel64
# ['', '/home1/02561/rtevans/.local/lib/python2.7/site-packages/argparse-1.2.1-py2.7.egg', '/home1/02561/rtevans/.local/lib/python2.7/site-packages/python_memcached-1.53-py2.7.egg', '/home1/02561/rtevans/.local/lib/python2.7/site-packages/South-1.0-py2.7.egg', '/home1/02561/rtevans/tacc_stats', '/home1/02561/rtevans/.local/lib/python2.7/site-packages/OBITools-1.0.beta-py2.7-linux-x86_64.egg', '/home1/02744/earnric/.local/lib/python2.7/site-packages/Cython-0.21.2-py2.7-linux-x86_64.egg', '/home1/02744/earnric/.local/lib/python2.7/site-packages/yt-3.1dev-py2.7-linux-x86_64.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/matplotlib-1.4.0-py2.7-linux-x86_64.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/mock-1.0.1-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/nose-1.3.4-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/pyparsing-2.0.3-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/python_dateutil-2.2-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/six-1.8.0-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/setuptools-3.1-py2.7.egg', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages/pip-1.5.6-py2.7.egg', '/home1/02561/rtevans/.local/lib/python2.7/site-packages', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python27.zip', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/plat-linux2', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/lib-tk', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/lib-old', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/lib-dynload', '/home1/02744/earnric/.local/lib/python2.7/site-packages', '/opt/apps/intel14/mvapich2_2_0/python/2.7.6/lib/python2.7/site-packages', '/home1/02561/rtevans/.local/lib/python2.7/site-packages/IPython/extensions']

# %%
import numpy as np
import os
import shutil
import h5py
import gc
import glob

# %%
# %matplotlib inline

# %%
ds = yt.load("./output_00008/info_00008.txt")
# Out:
# yt : [INFO     ] 2015-01-28 23:16:23,039 Parameters: current_time              = -1.02579902883e+16
# yt : [INFO     ] 2015-01-28 23:16:23,039 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2015-01-28 23:16:23,040 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2015-01-28 23:16:23,041 Parameters: domain_right_edge         = [ 1.  1.  1.]
# yt : [INFO     ] 2015-01-28 23:16:23,041 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2015-01-28 23:16:23,042 Parameters: current_redshift          = 24.0963731819
# yt : [INFO     ] 2015-01-28 23:16:23,042 Parameters: omega_lambda              = 0.73299998045
# yt : [INFO     ] 2015-01-28 23:16:23,042 Parameters: omega_matter              = 0.266999989748
# yt : [INFO     ] 2015-01-28 23:16:23,042 Parameters: hubble_constant           = 0.71

# %%
ad = ds.all_data()

# %%
#partIDs = ad.particles["particle_identifier"] # The "=" doesn't seem to add anything...

# %%
ds.domain_width.in_units("kpc")
# Out:
# YTArray([ 16.80552731,  16.80552731,  16.80552731]) kpc

# %%
physSize =ds.domain_width.in_units("kpc")[0]
print physSize
# Out:
# 16.805527307 kpc

# %%
z = "%.2f"%ds.current_redshift
print z
# Out:
# 24.10

# %%
zString = "z = %.2f" % ds.current_redshift
print zString
# Out:
# z = 24.10

# %%
# Make a density projection centered on the 'm'aximum density location
# with a width of 50 kpc..
p = yt.ProjectionPlot(ds, "y", "density", center='m', width=(5, 'kpc'))

# Modify the projection
# The argument specifies the region along the line of sight
# for which particles will be gathered.
# 1.0 signifies the entire domain in the line of sight
# p.annotate_particles(1.0)
# but in this case we only go 50 kpc in depth

#p.annotate_particles((50, 'kpc'))

p.annotate_title(zString)
p.show()
# Out:
# yt : [INFO     ] 2015-01-28 23:23:31,639 Max Value is 1.84985e-24 at 0.3200683593750000 0.4948730468750000 0.3225097656250000
# yt : [INFO     ] 2015-01-28 23:23:38,029 Projection completed
# yt : [INFO     ] 2015-01-28 23:23:38,048 xlim = 0.173749 0.471270
# yt : [INFO     ] 2015-01-28 23:23:38,048 ylim = 0.171308 0.468829
# yt : [INFO     ] 2015-01-28 23:23:38,049 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-28 23:23:38,063 xlim = 0.173749 0.471270
# yt : [INFO     ] 2015-01-28 23:23:38,063 ylim = 0.171308 0.468829
# yt : [INFO     ] 2015-01-28 23:23:38,064 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2015-01-28 23:23:38,076 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
dd = ds.all_data()

# %%
dd.quantities.total_mass()
# Out:
# [9.399991717e+41 g, 4.63733606621e+42 g]

# %%
ds.field_info("Density")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-437a8263dfc8> in <module>()
# ----> 1 ds.field_info("Density")
#
# TypeError: 'RAMSESFieldInfo' object is not callable

# %%
ad.field_parameters
# Out:
# {'bulk_velocity': YTArray([ 0.,  0.,  0.]) cm/s,
#  'center': YTArray([ 0.5,  0.5,  0.5]) code_length,
#  'normal': YTArray([ 0.,  0.,  1.]) (dimensionless)}

# %%
ds.field_list
# Out:
# [('ramses', 'Density'),
#  ('ramses', 'x-velocity'),
#  ('ramses', 'y-velocity'),
#  ('ramses', 'z-velocity'),
#  ('ramses', 'Pressure'),
#  ('ramses', 'Metallicity'),
#  ('ramses', 'var6'),
#  ('ramses', 'var7'),
#  ('ramses', 'var8'),
#  ('io', 'particle_refinement_level'),
#  ('io', 'particle_position_z'),
#  ('io', 'particle_position_x'),
#  ('io', 'particle_velocity_z'),
#  ('io', 'particle_velocity_x'),
#  ('io', 'particle_velocity_y'),
#  ('io', 'particle_position_y'),
#  ('io', 'particle_metallicity'),
#  ('io', 'particle_mass'),
#  ('io', 'particle_identifier'),
#  ('io', 'particle_age'),
#  ('all', 'particle_metallicity'),
#  ('all', 'particle_mass'),
#  ('all', 'particle_position_z'),
#  ('all', 'particle_position_x'),
#  ('all', 'particle_position_y'),
#  ('all', 'particle_age'),
#  ('all', 'particle_refinement_level'),
#  ('all', 'particle_identifier'),
#  ('all', 'particle_velocity_z'),
#  ('all', 'particle_velocity_x'),
#  ('all', 'particle_velocity_y')]

# %%
re = ds.region([0.5,0.5,0.5], [0.0,0.0,0.0], [1.0,1.0,1.0])

# %%
ds["particle_identifier"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-7ffa1a61c20c> in <module>()
# ----> 1 ds["particle_identifier"]
#
# /home1/02744/earnric/.local/lib/python2.7/site-packages/yt-3.1dev-py2.7-linux-x86_64.egg/yt/data_objects/static_output.pyc in __getitem__(self, key)
#     247     def __getitem__(self, key):
#     248         """ Returns units, parameters, or conversion_factors in that order. """
# --> 249         return self.parameters[key]
#     250
#     251     def __iter__(self):
#
# KeyError: 'particle_identifier'

# %%
ct = re["creation_time"]
# Out:
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# <ipython-input-28-0ad9a060935a> in <module>()
# ----> 1 ct = re["creation_time"]
#
# /home1/02744/earnric/.local/lib/python2.7/site-packages/yt-3.1dev-py2.7-linux-x86_64.egg/yt/data_objects/data_containers.pyc in __getitem__(self, key)
#     239         Returns a single field.  Will add if necessary.
#     240         """
# --> 241         f = self._determine_fields([key])[0]
#     242         if f not in self.field_data and key not in self.field_data:
#     243             if f in self._container_fields:
#
# /home1/02744/earnric/.local/lib/python2.7/site-packages/yt-3.1dev-py2.7-linux-x86_64.egg/yt/data_objects/data_containers.pyc in _determine_fields(self, fields)
#     495             else:
#     496                 fname = field
# --> 497                 finfo = self.ds._get_field_info("unknown", fname)
#     498                 if finfo.particle_type:
#     499                     ftype = self._current_particle_type
#
# /home1/02744/earnric/.local/lib/python2.7/site-packages/yt-3.1dev-py2.7-linux-x86_64.egg/yt/data_objects/static_output.pyc in _get_field_info(self, ftype, fname)
#     484                     self._last_finfo = self.field_info[(ftype, fname)]
#     485                     return self._last_finfo
# --> 486         raise YTFieldNotFound((ftype, fname), self)
#     487
#     488     def _setup_classes(self):
#
# YTFieldNotFound: Could not find field '('all', 'creation_time')' in info_00008.

# %%
import matplotlib.pyplot as plt

# %%
len(re["particle_position"])
# Out:
# 16779234

# %%
plt.plot(re["particle_position"][:,0],re["particle_position"][:,1],'.')
plt.title("Star particle locations z=%.1f\n2D projection, xy plane, %s boxsize"%(ds.current_redshift,physSize))

# %%
physSizeNC =

# %%
my_sphere = ds.sphere("c", physSizeNC)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c658bdd04ae6> in <module>()
# ----> 1 my_sphere = ds.sphere("c", physSizeNC)
#
# NameError: name 'physSizeNC' is not defined

# %%
# fractional=True keyword -- divide the profile data by the sum. 
plot2 = yt.PhasePlot(my_sphere, "density", "temperature", "cell_mass", weight_field=None, fractional=True )
plot2.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-943e2b30a3e3> in <module>()
#       1 # fractional=True keyword -- divide the profile data by the sum.
# ----> 2 plot2 = yt.PhasePlot(my_sphere, "density", "temperature", "cell_mass", weight_field=None, fractional=True )
#       3 plot2.show()
#
# NameError: name 'my_sphere' is not defined

# %%
plot2 = yt.PhasePlot(my_sphere, "density", "temperature", "cell_mass", weight_field=None, fractional=False )
plot2.show()
# Out:
# <img src="data:image/png;base64,..."><br>
