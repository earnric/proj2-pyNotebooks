# %%
# %matplotlib inline
from matplotlib.pylab import *
rcParams['figure.figsize'] = (12,8)
rcParams['font.size'] = 18

# %%
import pynbody
import pynbody.plot.sph as sph
pynbody.ramses.multiprocess_num = 256
pynbody.config['number_of_threads'] = 16

# %%
s = pynbody.load('/Users/earnric/Research/RAMSES-Data/13Aug-300kpc/output_00009')
# Out:
# INFO:pynbody:Loading using backend <class 'pynbody.snapshot.ramses.RamsesSnap'>

# %% [markdown]
# ## Look at the # of number of star, gas (cells) and DM particles

# %% [markdown]
# ### Note that in pynbody everything is considered a 'particle' -- i.e. - cells become particles in this model

# %%
len(s.stars),len(s.gas),len(s.dm)
# Out:
# (3, 26725266, 16777216)

# %% [markdown]
# ### Actually load the data. This is done when you ask for the data.

# %%
s['pos']
# Out:
# INFO:pynbody.snapshot.ramses:Loading hydro files
# INFO:pynbody.snapshot.ramses:Done
# INFO:pynbody.snapshot.ramses:Loading data from CPU 3
# INFO:pynbody.snapshot.ramses:Loading data from CPU 2
# INFO:pynbody.snapshot.ramses:Loading data from CPU 4
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1
# INFO:pynbody.snapshot.ramses:Loading data from CPU 8
# INFO:pynbody.snapshot.ramses:Loading data from CPU 7
# INFO:pynbody.snapshot.ramses:Loading data from CPU 9
# INFO:pynbody.snapshot.ramses:Loading data from CPU 5
# INFO:pynbody.snapshot.ramses:Loading data from CPU 6
# INFO:pynbody.snapshot.ramses:Loading data from CPU 11
# INFO:pynbody.snapshot.ramses:Loading data from CPU 10
# INFO:pynbody.snapshot.ramses:Loading data from CPU 13
# INFO:pynbody.snapshot.ramses:Loading data from CPU 12
# INFO:pynbody.snapshot.ramses:Loading data from CPU 14
# INFO:pynbody.snapshot.ramses:Loading data from CPU 15
# INFO:pynbody.snapshot.ramses:Loading data from CPU 16
# ...

# %%
s.properties
# Out:
# {'a': 0.10006299508803,
#  'boxsize': Unit("1.30e+23 cm"),
#  'h': 0.71,
#  'omegaL0': 0.732999980449677,
#  'omegaM0': 0.266999989748001,
#  'time': Unit("5.62e-01 Gyr")}

# %% [markdown]
# ### Print z for this output step

# %%
z=1/s.properties['a']-1

# %%
z
# Out:
# 8.993704457079804

# %%
s.properties['boxsize'].in_units('kpc')
# Out:
# 42.20231064637044

# %%
boxsizestring = "%.2f" % s.properties['boxsize'].in_units('kpc')

# %%
boxsizestring += " kpc"

# %%
boxsizestring
# Out:
# '42.20 kpc'

# %% [markdown]
# ### So comoving box size is ...

# %%
s.properties['boxsize'].in_units('kpc') * s.properties['h'] / s.properties['a']
# Out:
# 299.4477682040461

# %%
s.properties['time'].in_units('Myr')
# Out:
# 562.1631277116882

# %% [markdown]
# # NORMALIZE data coords -- center the values on (0,0,0)

# %% [markdown]
# ## RAMSES uses particle locations between 0 and 1... Shift this to -0.5 to 0.5

# %% [markdown]
# ## Do this BEFORE transforming to physical units

# %%
s['pos'] -= 0.5

# %%
s.physical_units()
# Out:
# INFO:pynbody.snapshot:Converting pos units from 1.30e+23 cm to kpc
# INFO:pynbody.snapshot:Converting vel units from 3.00e+07 cm s**-1 to km s**-1
# INFO:pynbody.snapshot:Converting tv units from 3.00e+07 cm s**-1 to km s**-1
# INFO:pynbody.snapshot:Converting smooth units from 1.30e+23 cm to kpc
# INFO:pynbody.snapshot:Converting p units from 2.27e-12 g cm**-1 s**-2 to km**2 Msol s**-2 kpc**-3
# INFO:pynbody.snapshot:Converting rho units from 2.53e-27 g cm**-3 to Msol kpc**-3

# %% [markdown]
# ## Zero-out metals lower than 10^-8

# %%
len(s.gas['metal'][s.gas['metal']< 1.0e-8])
# Out:
# 25016242

# %%
len(s.gas['metal'][s.gas['metal']>=1e-8])
# Out:
# 1709024

# %%
s.gas['metal'][s.gas['metal']<1e-8]=1.0e-8

# %%
len(s.gas['metal'][s.gas['metal']< 1.0e-8])
# Out:
# 0

# %% [markdown]
# ## Plot the metals in a slice at the center of the simulation box

# %% [markdown]
# #### Remember - you get a slice at box-center unless you ask for something else...

# %%
boxsizestring
# Out:
# '42.20 kpc'

# %%
titleStr = "Z @ z = %2d" % z + "\nSlice @ zAxis origin"
sph.image(s.g,qty="metal",width=boxsizestring,cmap="YlOrRd", denoise=False ,approximate_fast=False,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.snapshot:Deriving array mass

# %%
with pynbody.transformation.translate(s,[0,0,2]):
    titleStr = "Z @ z = %2d" % z + "\nSlice @ zAxis +2kpc"
    sph.image(s.g,qty="metal",width=boxsizestring,cmap="YlOrRd", av_z=False, denoise=False ,approximate_fast=False,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...

# %% [markdown]
# ### Plot the average Z through the sim box

# %%
titleStr = "Z @ z = %2d" % z + "\nVol Weighted Average"
sph.image(s.g,qty="metal",width=boxsizestring,cmap="YlOrRd", av_z=True, qtytitle="log10 Z",denoise=False ,
          approximate_fast=False,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %% [markdown]
# ## Look at the Pristine Gas Fraction scalar for the gas

# %%
s.g['pgf'][s.g['pgf']>1.0].size
# Out:
# 0

# %%
s.gas['pgf'][s.gas['pgf']<1e-8]=1e-8

# %%
s.g['pgf'][s.g['pgf']>1.0]=1.0

# %%
titleStr = "Pristine Gas Fraction @ z = %2d" % z + "\nVol Weighted Average"
sph.image(s.g,qty="pgf",width=boxsizestring,cmap="YlOrRd", av_z=True, qtytitle="log10 Pf", denoise=False ,
          approximate_fast=False,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %% [markdown]
# ## Other plots

# %%
#Plotting a slice at z=0
titleStr = "Mass density @ z = %2d" % z + "\nslice @ zCoord = 0"
pynbody.plot.image(s.g,width=boxsizestring, units='Msol kpc^-3', center=True, cmap=cm.jet,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
with pynbody.transformation.translate(s,[0,0,5]):
    titleStr = "Mass density @ z = %2d" % z + "\nslice @ zCoord = +5kpc"
    pynbody.plot.image(s.g,width=boxsizestring, center=True, cmap=cm.jet,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
#Projected Mass density on entire box - note units
titleStr = "Mass density @ z = %2d" % z + "\nVol Weighted Ave"
pynbody.plot.image(s.g,width=boxsizestring, units='Msol kpc^-2', center=True, cmap=cm.jet,title=titleStr);
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %% [markdown]
# # Plot the turbulent Mach #

# %%
s.g['tv']
# Out:
# SimArray([ 0.45609685,  0.80120609,  0.5850038 , ...,  0.57393478,
#         0.51274054,  0.66042852], 'km s**-1')

# %%
s.g['tv'][s.g['tv']<0.01].size
# Out:
# 0

# %%
s.g['cs']
# Out:
# INFO:pynbody.snapshot:Deriving array cs
# INFO:pynbody.snapshot:Deriving array temp
# INFO:pynbody.snapshot:Deriving array mu
# /Users/earnric/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pynbody/derived.py:218: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(5.0 * units.k * self['temp'] / self['mu'] / units.m_p)
# INFO:pynbody.snapshot:Converting temp units from 2.24e+00 K**1/2 k**1/2 m_p**-1/2 to km s**-1
# SimArray([ 0.2768881 ,  0.27450766,  0.27408443, ...,  0.43736034,
#         0.3775891 ,  0.32702911], 'km s**-1')

# %%
s.g['cs'][s.g['cs']<0.01].size
# Out:
# /Users/earnric/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pynbody/array.py:666: RuntimeWarning: invalid value encountered in less
#   return comparison_op(ar, other)
# 1

# %% [markdown]
# ## Defining a new quantity to plot

# %%
s.g['M']=s.g['cs']/s.g['tv']

# %%
sph.image(s.g,qty="M",width=boxsizestring,cmap="YlOrRd", av_z=True, qtytitle="Mach #", denoise=False ,
          approximate_fast=False,title="Turbulent Mach #");
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
with pynbody.transformation.translate(s,[0,0,0]):
    sph.image(s.g,qty="M",width=boxsizestring,cmap="YlOrRd", qtytitle="Mach #", denoise=False ,
              approximate_fast=False,title="Turbulent Mach # - Slice at zCoord=0");
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
with pynbody.transformation.translate(s,[0,0,10]):
    sph.image(s.g,qty="M",width=boxsizestring,cmap="YlOrRd", qtytitle="Mach #", denoise=False ,
              approximate_fast=False,title="Turbulent Mach # - Slice at zCoord=10");
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...

# %% [markdown]
# ## Plot temperature data

# %%
    sph.image(s.g,qty="temp",width=boxsizestring,cmap="YlOrRd", denoise=True ,av_z=False,
              approximate_fast=False,title="Gas Temp");
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.snapshot:Deriving array temp
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
    with pynbody.transformation.translate(s,[0,0,10]):
        sph.image(s.g,qty="temp",width=boxsizestring,cmap="YlOrRd", denoise=True ,av_z=False,
              approximate_fast=False,title="Gas Temp - Slice 10");
# Out:
# INFO:pynbody.sph:Rendering image on 16 threads...
# INFO:pynbody.sph:Rendering image on 16 threads...

# %%
# density weighted average temperature
# The "with" stuff that specified a slice makes NO difference here!
with pynbody.transformation.translate(s,[0,0,10]):
        sph.image(s.g,qty="temp",width='60.1 kpc',cmap="YlOrRd", denoise=True ,av_z="rho",
              approximate_fast=False,title="Gas Temp - rho weighted through volume");
# Out:
# 214214176 328
# Rendering image on 8 threads...
# 214214176
#  328
# Rendering image on 8 threads...
# Rendering image on 8 threads...
# 214214176
#  328
# Rendering image on 8 threads...

# %%
sph.image(s.g,qty="temp",width='60.1 kpc',cmap="YlOrRd", denoise=True ,av_z="rho",
          approximate_fast=False,title="Gas Temp - weighted average through volume (rho)");
# Out:
# 214214176 328
# Rendering image on 8 threads...
# 214214176
#  328
# Rendering image on 8 threads...
# Rendering image on 8 threads...
# 214214176
#  328
# Rendering image on 8 threads...
